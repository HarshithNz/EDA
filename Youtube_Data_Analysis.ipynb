# %%
! unzip '/content/drive/MyDrive/ytubeeee.zip'
# Out:
# Archive:  /content/drive/MyDrive/ytubeeee.zip
#   inflating: CA_category_id.json
#   inflating: CAvideos.csv
#   inflating: DE_category_id.json
#   inflating: DEvideos.csv
#   inflating: FR_category_id.json
#   inflating: FRvideos.csv
#   inflating: GB_category_id.json
#   inflating: GBvideos.csv
#   inflating: IN_category_id.json
#   inflating: INvideos.csv
#   inflating: JP_category_id.json
#   inflating: JPvideos.csv
#   inflating: KR_category_id.json
#   inflating: KRvideos.csv
#   inflating: MX_category_id.json
#   inflating: MXvideos.csv
#   inflating: RU_category_id.json
#   inflating: RUvideos.csv
#   inflating: US_category_id.json
#   inflating: USvideos.csv

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/USvideos.csv")

# %%
df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# ...

# %%
df.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
df.isnull().sum()
# Out:
# video_id                    0
# trending_date               0
# title                       0
# channel_title               0
# category_id                 0
# publish_time                0
# tags                        0
# views                       0
# likes                       0
# dislikes                    0
# comment_count               0
# thumbnail_link              0
# comments_disabled           0
# ratings_disabled            0
# video_error_or_removed      0
# description               570
# dtype: int64

# %%
df.drop(["thumbnail_link","description"],axis=1,inplace=True)

# %%
df["publish_time"]=pd.to_datetime(df["publish_time"])

# %%
df["trending_date"].unique()
# Out:
# array(['17.14.11', '17.15.11', '17.16.11', '17.17.11', '17.18.11',
#        '17.19.11', '17.20.11', '17.21.11', '17.22.11', '17.23.11',
#        '17.24.11', '17.25.11', '17.26.11', '17.27.11', '17.28.11',
#        '17.29.11', '17.30.11', '17.01.12', '17.02.12', '17.03.12',
#        '17.04.12', '17.05.12', '17.06.12', '17.07.12', '17.08.12',
#        '17.09.12', '17.10.12', '17.11.12', '17.12.12', '17.13.12',
#        '17.14.12', '17.15.12', '17.16.12', '17.17.12', '17.18.12',
#        '17.19.12', '17.20.12', '17.21.12', '17.22.12', '17.23.12',
#        '17.24.12', '17.25.12', '17.26.12', '17.27.12', '17.28.12',
#        '17.29.12', '17.30.12', '17.31.12', '18.01.01', '18.02.01',
#        '18.03.01', '18.04.01', '18.05.01', '18.06.01', '18.07.01',
#        '18.08.01', '18.09.01', '18.12.01', '18.13.01', '18.14.01',
#        '18.15.01', '18.16.01', '18.17.01', '18.18.01', '18.19.01',
#        '18.20.01', '18.21.01', '18.22.01', '18.23.01', '18.24.01',
# ...

# %%
df["trending_date"]=pd.to_datetime(df["trending_date"],format="%y.%d.%m")

# %%
import datetime as dt

# %%
df["p_year"]=df["publish_time"].dt.year

# %%
df["p_month"]=df["publish_time"].dt.month_name()

# %%
df["t_year"]=df["trending_date"].dt.year

# %%
df["t_month"]=df["trending_date"].dt.month_name()

# %%
df.head(5)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE    2017-11-14
# 1  1ZAPwfrtAFY    2017-11-14
# 2  5qpjK5DgCt4    2017-11-14
# 3  puqaWrEC7tY    2017-11-14
# 4  d380meD0W0M    2017-11-14
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22 2017-11-13 17:13:01+00:00
# 1           24 2017-11-13 07:30:00+00:00
# 2           23 2017-11-12 19:05:24+00:00
# 3           24 2017-11-13 11:00:04+00:00
# 4           24 2017-11-12 18:01:41+00:00
#
# ...

# %%
df[df["video_id"]=="5qpjK5DgCt4"]
# Out:
#          video_id trending_date  \
# 2     5qpjK5DgCt4    2017-11-14
# 238   5qpjK5DgCt4    2017-11-15
# 475   5qpjK5DgCt4    2017-11-16
# 713   5qpjK5DgCt4    2017-11-17
# 954   5qpjK5DgCt4    2017-11-18
# 1181  5qpjK5DgCt4    2017-11-19
# 1392  5qpjK5DgCt4    2017-11-20
#
#                                                   title channel_title  \
# 2     Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 238   Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 475   Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 713   Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 954   Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 1181  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 1392  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
#
#       category_id              publish_time  \
# 2              23 2017-11-12 19:05:24+00:00
# 238            23 2017-11-12 19:05:24+00:00
# ...

# %%
df["video_id"].nunique()
# Out:
# 6351

# %%
yt=df.groupby("p_year")

# %%
yt.count().sort_values(by="video_id",ascending=False)
# Out:
#         video_id  trending_date  title  channel_title  category_id  \
# p_year
# 2018       30279          30279  30279          30279        30279
# 2017       10428          10428  10428          10428        10428
# 2013          44             44     44             44           44
# 2015          35             35     35             35           35
# 2016          35             35     35             35           35
# 2014          32             32     32             32           32
# 2011          27             27     27             27           27
# 2012          24             24     24             24           24
# 2010          19             19     19             19           19
# 2009          14             14     14             14           14
# 2008          11             11     11             11           11
# 2006           1              1      1              1            1
#
#         publish_time   tags  views  likes  dislikes  comment_count  \
# p_year
# ...

# %%
vid=df.groupby("video_id")

# %%
vid=vid.max()

# %%
vid.reset_index(inplace=True)

# %%
vid
# Out:
#          video_id trending_date  \
# 0     -0CMnp02rNY    2018-06-11
# 1     -0NYY8cqdiQ    2018-02-01
# 2     -1Hm41N0dUs    2018-05-01
# 3     -1yT-K3c6YI    2017-12-02
# 4     -2RVw2_QyxQ    2017-11-16
# ...           ...           ...
# 6346  zwEn-ambXLw    2018-04-06
# 6347  zxUwbflE1SY    2017-11-19
# 6348  zxwfDlhJIpw    2018-05-25
# 6349  zy0b9e40tK8    2017-11-14
# 6350  zzQsGL_F9_c    2018-02-06
#
#                                                   title  \
# 0     Mindy Kaling's Daughter Had the Perfect Reacti...
# 1     Megan Mullally Didn't Notice the Interesting P...
# 2     Cast of Avengers: Infinity War Draws Their Cha...
# 3     YOUTUBER QUIZ + TRUTH OR DARE W/ THE MERRELL T...
# 4                        2017 Champions Showdown: Day 3
# ...                                                 ...
# 6346  This Is Me - Cover by Shoshana Bean Featuring ...
# 6347  100 People Hold Their Breath for as Long as Th...
# 6348                 kanye west / charlamagne interview
# ...

# %%
vid.to_csv("myyoutube.csv",index=False)
